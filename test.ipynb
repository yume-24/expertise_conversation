# %%
from random import expovariate

import pandas as pd
expert_stats = pd.read_csv('/Users/yume/PycharmProjects/horizons_2/outputs/experts_graph_stats.csv')
novice_stats = pd.read_csv('/Users/yume/PycharmProjects/horizons_2/outputs/novices_graph_stats.csv')

# %%
expert_stats['density'].mean()
# Out:
# np.float64(0.009965451065619618)

# %%
novice_stats['density'].mean()
# Out:
# np.float64(0.015437115518418702)

# %%
expert_stats['avg_shortest_path_length'].mean()
# Out:
# np.float64(6.7110045563378575)
